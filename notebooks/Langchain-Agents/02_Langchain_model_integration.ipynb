# %%
import os
from dotenv import load_dotenv

# Change working directory to the parent folder (01_Langchain)
os.chdir(os.path.abspath(".."))
load_dotenv()
# Out:
# True

# %%
os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("gpt-5")
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.6.3', 'langchain': '1.4.2', 'langchain-openai': '1.6.2'}}, profile={'name': 'GPT-5', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True, 'reasoning_effort_levels': ['minimal', 'low', 'medium', 'high']}, client=<openai.resources.chat.completions.completions.Completions object at 0x1111c17f0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x1111c2270>, root_client=<openai.OpenAI object at 0x1111c0980>, root_async_client=<openai.AsyncOpenAI object at 0x1111c1fd0>, model_name='gpt-5', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
response = model.invoke("Hello how are you?")
response.content
# Out:
# 'Hi! I’m doing well, thanks for asking. How can I help you today?'

# %%
## Call google gemimi model integration
from langchain.chat_models import init_chat_model
gemini_model = init_chat_model("google_genai:gemini-3.5-flash-lite")

response = gemini_model.invoke("Why do parrots talk")
response.content
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# [{'type': 'text',
#   'text': 'Parrots talk primarily because of **social integration, high intelligence, and a biological need to communicate.** \n\nIn the wild, talking is a matter of survival. In human homes, that same natural instinct gets redirected toward human speech. \n\nHere is a breakdown of why parrots talk:\n\n### 1. They are "Flock" Animals (Social Bonding)\nIn the wild, parrots live in large flocks. To survive, individual birds need to fit in. They do this by learning the "dialect" of their flock. \n* **Mimicry as bonding:** Parrots use mimicry to strengthen bonds with their family members (in captivity, their human owners). By sounding like you, they are essentially saying, *"I am part of your family/flock."*\n\n### 2. High Intelligence and Boredom\nParrots are exceptionally smart—some species have the cognitive and emotional intelligence of a 4-to-6-year-old human child. \n* **Mental stimulation:** Captiacated parrots have complex brains that need stimulation. If they are bored, they will learn to talk just to entertain themselves or get a reaction out of you. \n\n### 3. Attention-Seeking and Reward (Operant Conditioning)\nParrots quickly learn cause and effect. \n* If a parrot says "Hello!" or mimics the microwave, and you look at them, laugh, or give them a treat, **they learn that talking gets results.** \n* Even negative reactions (like yelling "Quiet!" when they scream or squawk) can teach a parrot to repeat certain sounds because they successfully got your attention.\n\n### 4. Environmental Sound Mimicry\nParrots don\'t have vocal cords like humans; instead, they use an organ called a **syrinx** to push air and manipulate sounds. They are natural-born mimics. In the wild, they copy other birds, predators, and environmental sounds to blend in or warn others. In your house, the "flock sounds" happen to be:\n* The microwave beeping\n* The phone ringing\n* The dog barking\n* You swearing when you stub your toe\n\n### Do they understand what they are saying?\nUsually, no. Parrots are generally mimicking sounds associated with contexts, rather than understanding grammar or vocabulary. For example, a parrot might say "Want a cracker?" not because it knows it\'s a question, but because it has learned that saying those exact sounds usually results in getting food.\n\n*(Note: Famous exceptions, like Alex the African Grey studied by Dr. Irene Pepperberg, proved that some parrots can learn to use words meaningfully and grasp concepts like shape, color, and number—but this requires intensive, specialized training.)*',
#   'extras': {'signature': 'El4KXAFpFH0Tglo1upmZ+aU3bQi9iZdogsL3bGY9ID+cxLkLZf9IB0ojyzvwab1ZV0IKsozRNYLy5Kw1tRZBiMBUArday4R5fM9g6+x9ikt2LPxM6bsH5gx+3eT4Nm0N'}}]

# %% [markdown]
# ## Chat OpenAI

# %%
## chat open ai 
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-5")
response=model.invoke("tell me a joke")
response.content
# Out:
# 'Parallel lines have so much in common—it’s a shame they’ll never meet.'

# %% [markdown]
# ## Chat Google

# %%
## Chat google generative ai 

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.5-flash-lite")
response=model.invoke("Tell me a joke")
print(response.text)
# Out:
# Why don't scientists trust atoms?
#
# Because they make up everything!

# %% [markdown]
# ## GROQ models

# %%
## Groq models

from langchain.chat_models import init_chat_model
model = init_chat_model("groq:qwen/qwen3.8-27b")
response = model.invoke("Tell me a joke")
response.content
# Out:
# 'Why did the scarecrow win an award?\n\nBecause he was outstanding in his field! 🌾'

# %% [markdown]
# ## Chat GROQ

# %%
## Chat Groq model

from langchain_groq import ChatGroq

model = ChatGroq(model="qwen/qwen3.8-27b")
response=model.invoke("Tell me a joke")
response.content
# Out:
# 'Why don’t scientists trust atoms?\n\nBecause they make up everything! 🧪😄'
